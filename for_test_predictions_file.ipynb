# %%
# %pylab inline
import theano
import theano.tensor as TT
import lasagne
import lasagne.layers as LL
import lasagne.nonlinearities as LN
import lasagne.init as LI
from common.plotting import plot_mat


from fuel.datasets.cifar10 import CIFAR10
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme
CIFAR10.default_transformers = ((ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
                                (Cast, [np.float32], {'which_sources': 'features'}))
cifar10_train = CIFAR10(("train",), subset=slice(None,40000))
# this stream will shuffle the CIFAR10 set and return us batches of 100 examples
cifar10_train_stream = DataStream.default_stream(cifar10_train,
                                                 iteration_scheme=ShuffledScheme(cifar10_train.num_examples, 25))
cifar10_validation = CIFAR10(("train",), subset=slice(40000, None))
# We will use larger portions for testing and validation
# as these dont do a backward pass and reauire less RAM.
cifar10_validation_stream = DataStream.default_stream(cifar10_validation,
                                                      iteration_scheme=SequentialScheme(cifar10_validation.num_examples,
                                                                                        100))
cifar10_test = CIFAR10(("test",))
cifar10_test_stream = DataStream.default_stream(cifar10_test,
                                                iteration_scheme=SequentialScheme(cifar10_test.num_examples, 100))


# Check print
print "The streams return batches containing %s" % (cifar10_train_stream.sources,)
print "Each trainin batch consits of a tuple containing:"
for element in next(cifar10_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
print "Validation/test batches consits of tuples containing:"
for element in next(cifar10_test_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 22 days
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 22 days
# Using gpu device 0: GeForce GTX 780 (CNMeM is enabled)
# /home/i265983/Dokumenty/nn_assignments/libs/Theano/theano/tensor/signal/downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")
# Populating the interactive namespace from numpy and matplotlib
# The streams return batches containing (u'features', u'targets')
# Each trainin batch consits of a tuple containing:
#  - an array of size (25, 3, 32, 32) containing float32
#  - an array of size (25, 1) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (100, 3, 32, 32) containing float32
#  - an array of size (100, 1) containing uint8

# %%
class ConvNeuralNet:
    wdec_layers = [LL.Conv2DLayer, LL.DenseLayer]
    def __init__(self, input_var, target_var, layers, data_shape, batch_size=None):
        self.input_var = input_var
        self.target_var = target_var
        self.layers = [LL.InputLayer(shape=(batch_size,)+data_shape,
                                     input_var=self.input_var)]
        for layer in layers:
            if layer['type'] == LL.DenseLayer and 'W' not in layer['args']:
                shape = LL.get_output_shape(self.layers[-1])
                layer['args']['W'] = LI.Uniform(range=(1. / np.sqrt(shape[1])))
            self.layers.append(layer['type'](incoming=self.layers[-1], **layer['args']))
        self.network = self.layers[-1]
        self.wdec = lasagne.regularization.regularize_network_params(self.network,
                                                                     lasagne.regularization.l2)
        
    def initialize(self, learning_rate, momentum, wdec_const):
        self.learning_rate = learning_rate
        self.momentum = momentum
        self.wdec_const = wdec_const
        
        self.prediction = LL.get_output(self.network, deterministic=False)
        self.loss = lasagne.objectives.categorical_crossentropy(self.prediction, self.target_var)
        self.loss = self.loss.mean() + self.wdec_const * self.wdec
        
        self.params = LL.get_all_params(self.network, trainable=True)
        # https://blogs.princeton.edu/imabandit/2013/04/01/acceleratedgradientdescent/
        self.updates = lasagne.updates.nesterov_momentum(self.loss,
                                                self.params,
                                                learning_rate=self.learning_rate,
                                                momentum=self.momentum)
        
        self.train_acc = TT.mean(TT.eq(TT.argmax(self.prediction, axis=1), self.target_var),
                                 dtype=theano.config.floatX)
        
        self.test_prediction = LL.get_output(self.network, deterministic=True)
        self.test_loss = lasagne.objectives.categorical_crossentropy(self.test_prediction,
                                                                     self.target_var)
        self.test_loss = self.test_loss.mean()
        self.test_acc = TT.mean(TT.eq(TT.argmax(self.test_prediction, axis=1), self.target_var),
                                dtype=theano.config.floatX)
        
        self.train_fn = theano.function([self.input_var, self.target_var],
                                        [self.loss, self.train_acc],
                                        updates=self.updates)
        self.val_fn = theano.function([self.input_var, self.target_var],
                                      [self.test_loss, self.test_acc])
        self.test_prediction_fn = theano.function([self.input_var], [self.test_prediction])

# %%
import copy

class Transform(object):
    def __init__(self, rng=None):
        if rng == None:
            rng = numpy.random
        self.rng = rng
    
    def transform(self, X):
        return X
    
    def name(self):
        return "Identity transformation"

class Shift(Transform):
    def __init__(self, shift_size=4, **kwargs):
        super(Shift, self).__init__(**kwargs)
        self.shift_size = shift_size
        
    def transform(self, X):
        res = copy.copy(X)
        for i in xrange(res.shape[0]):
            res[i] = np.roll(res[i], self.rng.randint(-self.shift_size, self.shift_size + 1), axis=1)
            res[i] = np.roll(res[i], self.rng.randint(-self.shift_size, self.shift_size + 1), axis=2)
        return res
    
    def name(self):
        return "Random shift by %d" % self.shift.size
    
class HorizontalFlip(Transform):
    def __init__(self, **kwargs):
        super(HorizontalFlip, self).__init__(**kwargs)
        
    def transform(self, X):
        res = copy.copy(X)
        for i in xrange(res.shape[0]):
            res[i] = res[i][:,:,::-1,...]
        return res
    
    def name(self):
        return "Horizontal flip"
    
trans = [trans() for trans in Transform.__subclasses__()]
def random_transform(X_batch):
    global trans
    return trans[np.random.randint(0, len(trans))].transform(X_batch)

# example of transformation
for X_batch, Y_batch in cifar10_train_stream.get_epoch_iterator():
    X = X_batch
    break
X = random_transform(X[:10])
plot_mat(X, cmap='gray')

# %%
input_var = TT.tensor4('inputs')
target_var = TT.ivector('targets')

net = ConvNeuralNet(input_var, target_var,
                    layers=[{'type' : LL.Conv2DLayer,
                             'args' : {'num_filters' : 50,
                                       'filter_size' : (5,5),
                                       'nonlinearity' : LN.rectify,
                                       'W' : LI.Normal(std=0.05,mean=0.0)}},
                            {'type' : LL.MaxPool2DLayer,
                             'args' : {'pool_size' : (2,2)}},
                            {'type' : LL.DropoutLayer,
                             'args' : {'p' : 0.2}},
                            {'type' : LL.Conv2DLayer,
                             'args' : {'num_filters' : 100,
                                       'filter_size' : (5,5),
                                       'nonlinearity' : LN.rectify,
                                       'W' : LI.Normal(std=0.05,mean=0.0)}},
                            {'type' : LL.MaxPool2DLayer,
                             'args' : {'pool_size' : (2,2)}},
                            {'type' : LL.DropoutLayer,
                             'args' : {'p' : 0.2}},
                            {'type' : LL.FlattenLayer,
                             'args' : {}},
                            {'type' : LL.DenseLayer,
                             'args' : {'num_units' : 500,
                                       'nonlinearity' : LN.rectify}},
                            {'type' : LL.DropoutLayer,
                             'args' : {'p' : 0.5}},
                            {'type' : LL.DenseLayer,
                             'args' : {'num_units' : 500,
                                       'nonlinearity' : LN.rectify}},
                            {'type' : LL.DropoutLayer,
                             'args' : {'p' : 0.5}},
                            {'type' : LL.DenseLayer,
                             'args' : {'num_units' : 100,
                                       'nonlinearity' : LN.rectify}},
                            {'type' : LL.DropoutLayer,
                             'args' : {'p' : 0.5}},
                            {'type' : LL.DenseLayer,
                             'args' : {'num_units' : 10,
                                       'nonlinearity' : LN.softmax}}
                    ],
                    data_shape = (3,32,32))

l_rate = theano.shared(np.array(0.01, dtype=theano.config.floatX))
momentum = 0.9
wdec_const = 1e-3
net.initialize(l_rate, momentum, wdec_const)
# Out:
# /home/i265983/.local/lib/python2.7/site-packages/lasagne/layers/conv.py:489: UserWarning: The `image_shape` keyword argument to `tensor.nnet.conv2d` is deprecated, it has been renamed to `input_shape`.
#   border_mode=border_mode)

# %%
def snapshot_params(net):
    return LL.get_all_param_values(net.network)
def load_params(net, params):
    LL.set_all_param_values(net.network, params)
    
def compute_error_rate(stream, net):
    accs = 0.0
    loss = 0.0
    num_batches = 0.0
    for X, Y in stream.get_epoch_iterator():
        batch_loss, batch_acc = net.val_fn(X,Y.ravel())
        loss += batch_loss
        accs += batch_acc
        num_batches += 1
    return loss/num_batches, 1 - accs/num_batches

# %%
# I have had some connection problems so I need to load saved data and continue learning

import pickle

best_params = pickle.load(open('LasagneTest.pkl', 'r'))
load_params(net, best_params)
_, best_valid_error_rate = compute_error_rate(cifar10_validation_stream, net)
best_params_epoch = 0

i = pickle.load(open('LasagneTest_i.pkl', 'r'))
e = pickle.load(open('LasagneTest_e.pkl', 'r'))
number_of_epochs = pickle.load(open('LasagneTest_number_of_epochs.pkl', 'r'))

# %%
import time
import pickle
from datetime import datetime

#i=0
#e=0

#best_valid_error_rate = np.inf
#best_params_epoch = 0
#best_params = snapshot_params(net)

train_erros = []
train_losses = []
validation_errors = []

#number_of_epochs = 5
patience_expansion = 2.

base_lrate = 1e-2
K = 10000

# training loop
try:
    print "Learning started at %02d:%02d:%02d" % (datetime.now().hour, datetime.now().minute, datetime.now().second)
    while e < number_of_epochs: #This loop goes over epochs
        e += 1

        epoch_start_i = i
        train_loss = 0.0
        train_acc = 0.0
        start_time = time.time()
        for X_batch, Y_batch in cifar10_train_stream.get_epoch_iterator(): 
            i += 1
            X_batch = random_transform(X_batch)
            net.learning_rate.set_value(base_lrate * K / np.maximum(K, i))
            batch_loss, batch_acc = net.train_fn(X_batch, Y_batch.ravel())
            train_loss += batch_loss
            train_acc += batch_acc
            if i % 40 == 0:
                print '.',
            
        val_loss, val_error_rate = compute_error_rate(cifar10_validation_stream, net)
        if val_error_rate < best_valid_error_rate:
            number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
            best_valid_error_rate = val_error_rate
            best_params = snapshot_params(net)
            best_params_epoch = e
            pickle.dump(best_params, open('LasagneTest.pkl', 'w'))
            pickle.dump(e, open('LasagneTest_e.pkl', 'w'))
            pickle.dump(i, open('LasagneTest_i.pkl', 'w'))
            pickle.dump(number_of_epochs, open('LasagneTest_number_of_epochs.pkl', 'w'))

        train_batches = i - epoch_start_i
        validation_errors.append((i,val_error_rate))
        train_losses.append((i,train_loss / train_batches))
        train_erros.append((i,1-train_acc / train_batches))
        print "\nEpoch %d took %.3fs, currently going to do %d" % (e, time.time() - start_time,
                                                                   number_of_epochs)
        print "  training loss: %.6f, validation loss: %.6f" % (train_loss / train_batches, val_loss)
        print "  validation accuracy:\t\t%.2f%%" % (100 - val_error_rate * 100)
        print "  training accuracy:\t\t%.2f%%" % (train_acc / train_batches * 100)
except KeyboardInterrupt:
    print "\nKeyboard interruption, user stopped learning"

print "Learning ended at %02d:%02d:%02d" % (datetime.now().hour,
                                            datetime.now().minute,
                                            datetime.now().second)
    
print "Setting network parameters from after epoch %d" % (best_params_epoch)
load_params(net, best_params)

_, test_err_rate = compute_error_rate(cifar10_test_stream, net)
print "Test error rate: %f%%" % (test_err_rate)

# subplot(2,1,1)
# train_losses = np.array(train_losses)
# semilogy(train_losses[:,0], train_losses[:,1], label='batch train loss')
# legend()

# subplot(2,1,2)
train_erros = np.array(train_erros)
plot(train_erros[:,0], train_erros[:,1], label='batch train err rate')
validation_errors = np.array(validation_errors)
plot(validation_errors[:,0], validation_errors[:,1], label='validation err rate', color='r')
ylim(0,0.4)
legend(loc='lower left')
# Out:
# Learning started at 17:00:44
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1271 took 89.535s, currently going to do 2541
#   training loss: 0.675066, validation loss: 0.415995
#   validation accuracy:		86.27%
#   training accuracy:		88.98%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1272 took 88.903s, currently going to do 2541
#   training loss: 0.669789, validation loss: 0.416235
#   validation accuracy:		86.40%
#   training accuracy:		89.01%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1273 took 88.764s, currently going to do 2541
#   training loss: 0.668129, validation loss: 0.419192
#   validation accuracy:		86.14%
#   training accuracy:		88.99%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1274 took 88.729s, currently going to do 2541
#   training loss: 0.667110, validation loss: 0.419475
#   validation accuracy:		86.12%
#   training accuracy:		88.89%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1275 took 88.422s, currently going to do 2541
#   training loss: 0.674362, validation loss: 0.417532
#   validation accuracy:		86.35%
#   training accuracy:		88.98%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1276 took 78.804s, currently going to do 2541
#   training loss: 0.675028, validation loss: 0.420182
#   validation accuracy:		86.20%
#   training accuracy:		88.89%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1277 took 74.050s, currently going to do 2541
#   training loss: 0.676844, validation loss: 0.416931
#   validation accuracy:		85.99%
#   training accuracy:		88.86%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1278 took 88.685s, currently going to do 2541
#   training loss: 0.673166, validation loss: 0.423863
#   validation accuracy:		86.07%
#   training accuracy:		88.99%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1279 took 88.332s, currently going to do 2541
#   training loss: 0.671726, validation loss: 0.422794
#   validation accuracy:		86.18%
#   training accuracy:		88.87%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1280 took 88.030s, currently going to do 2541
#   training loss: 0.665681, validation loss: 0.419579
#   validation accuracy:		86.13%
#   training accuracy:		89.14%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1281 took 88.257s, currently going to do 2541
#   training loss: 0.673366, validation loss: 0.417449
#   validation accuracy:		86.37%
#   training accuracy:		88.85%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1282 took 88.213s, currently going to do 2541
#   training loss: 0.679525, validation loss: 0.419148
#   validation accuracy:		86.08%
#   training accuracy:		88.61%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1283 took 88.095s, currently going to do 2541
#   training loss: 0.668853, validation loss: 0.414670
#   validation accuracy:		86.32%
#   training accuracy:		88.99%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1284 took 88.078s, currently going to do 2541
#   training loss: 0.668192, validation loss: 0.418307
#   validation accuracy:		86.04%
#   training accuracy:		88.95%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1285 took 88.197s, currently going to do 2541
#   training loss: 0.665108, validation loss: 0.419577
#   validation accuracy:		86.15%
#   training accuracy:		89.17%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1286 took 88.242s, currently going to do 2541
#   training loss: 0.664138, validation loss: 0.415920
#   validation accuracy:		86.32%
#   training accuracy:		89.18%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1287 took 63.705s, currently going to do 2541
#   training loss: 0.680879, validation loss: 0.420257
#   validation accuracy:		86.26%
#   training accuracy:		88.60%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1288 took 88.216s, currently going to do 2541
#   training loss: 0.673470, validation loss: 0.418838
#   validation accuracy:		86.26%
#   training accuracy:		88.97%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1289 took 87.861s, currently going to do 2541
#   training loss: 0.671822, validation loss: 0.420920
#   validation accuracy:		86.30%
#   training accuracy:		88.87%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1290 took 88.214s, currently going to do 2541
#   training loss: 0.672714, validation loss: 0.417896
#   validation accuracy:		86.34%
#   training accuracy:		88.95%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1291 took 87.838s, currently going to do 2541
#   training loss: 0.683999, validation loss: 0.418158
#   validation accuracy:		86.37%
#   training accuracy:		88.58%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1292 took 88.287s, currently going to do 2541
#   training loss: 0.665627, validation loss: 0.418629
#   validation accuracy:		86.25%
#   training accuracy:		89.06%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1293 took 88.672s, currently going to do 2541
#   training loss: 0.668122, validation loss: 0.424999
#   validation accuracy:		86.08%
#   training accuracy:		88.93%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1294 took 88.136s, currently going to do 2541
#   training loss: 0.670328, validation loss: 0.412423
#   validation accuracy:		86.41%
#   training accuracy:		89.03%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1295 took 88.362s, currently going to do 2541
#   training loss: 0.672479, validation loss: 0.416799
#   validation accuracy:		86.16%
#   training accuracy:		88.81%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1296 took 88.162s, currently going to do 2541
#   training loss: 0.674940, validation loss: 0.415901
#   validation accuracy:		86.34%
#   training accuracy:		88.81%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1297 took 77.326s, currently going to do 2541
#   training loss: 0.663816, validation loss: 0.418410
#   validation accuracy:		86.28%
#   training accuracy:		89.15%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1298 took 75.365s, currently going to do 2541
#   training loss: 0.669959, validation loss: 0.419603
#   validation accuracy:		86.16%
#   training accuracy:		89.10%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1299 took 88.152s, currently going to do 2541
#   training loss: 0.672304, validation loss: 0.416491
#   validation accuracy:		86.55%
#   training accuracy:		89.07%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1300 took 88.008s, currently going to do 2541
#   training loss: 0.673910, validation loss: 0.418330
#   validation accuracy:		86.33%
#   training accuracy:		88.89%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1301 took 88.080s, currently going to do 2541
#   training loss: 0.666993, validation loss: 0.417086
#   validation accuracy:		86.34%
#   training accuracy:		89.06%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1302 took 88.226s, currently going to do 2541
#   training loss: 0.669386, validation loss: 0.415957
#   validation accuracy:		86.38%
#   training accuracy:		88.99%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1303 took 88.332s, currently going to do 2541
#   training loss: 0.674264, validation loss: 0.418428
#   validation accuracy:		86.34%
#   training accuracy:		88.82%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1304 took 87.775s, currently going to do 2541
#   training loss: 0.666204, validation loss: 0.418127
#   validation accuracy:		86.35%
#   training accuracy:		89.23%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1305 took 88.078s, currently going to do 2541
#   training loss: 0.668146, validation loss: 0.420996
#   validation accuracy:		86.31%
#   training accuracy:		89.04%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1306 took 88.300s, currently going to do 2541
#   training loss: 0.663495, validation loss: 0.418229
#   validation accuracy:		86.19%
#   training accuracy:		89.34%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1307 took 87.698s, currently going to do 2541
#   training loss: 0.668973, validation loss: 0.417705
#   validation accuracy:		86.46%
#   training accuracy:		89.16%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1308 took 63.810s, currently going to do 2541
#   training loss: 0.662709, validation loss: 0.417945
#   validation accuracy:		86.29%
#   training accuracy:		89.22%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1309 took 87.815s, currently going to do 2541
#   training loss: 0.667491, validation loss: 0.414509
#   validation accuracy:		86.39%
#   training accuracy:		89.24%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1310 took 88.181s, currently going to do 2541
#   training loss: 0.671081, validation loss: 0.420813
#   validation accuracy:		86.23%
#   training accuracy:		89.04%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1311 took 87.624s, currently going to do 2541
#   training loss: 0.668400, validation loss: 0.418175
#   validation accuracy:		86.45%
#   training accuracy:		88.88%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1312 took 88.229s, currently going to do 2541
#   training loss: 0.675065, validation loss: 0.414339
#   validation accuracy:		86.37%
#   training accuracy:		88.85%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1313 took 87.740s, currently going to do 2541
#   training loss: 0.667138, validation loss: 0.416591
#   validation accuracy:		86.42%
#   training accuracy:		89.18%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1314 took 88.377s, currently going to do 2541
#   training loss: 0.680194, validation loss: 0.416600
#   validation accuracy:		86.25%
#   training accuracy:		88.65%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1315 took 88.058s, currently going to do 2541
#   training loss: 0.672389, validation loss: 0.418185
#   validation accuracy:		86.18%
#   training accuracy:		88.88%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1316 took 88.023s, currently going to do 2541
#   training loss: 0.670251, validation loss: 0.417425
#   validation accuracy:		86.32%
#   training accuracy:		88.99%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1317 took 88.103s, currently going to do 2541
#   training loss: 0.670386, validation loss: 0.417880
#   validation accuracy:		86.33%
#   training accuracy:		88.98%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1318 took 76.953s, currently going to do 2541
#   training loss: 0.673152, validation loss: 0.419619
#   validation accuracy:		86.21%
#   training accuracy:		88.87%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1319 took 75.256s, currently going to do 2541
#   training loss: 0.670456, validation loss: 0.422905
#   validation accuracy:		86.33%
#   training accuracy:		89.10%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1320 took 88.478s, currently going to do 2541
#   training loss: 0.672105, validation loss: 0.421013
#   validation accuracy:		86.07%
#   training accuracy:		88.80%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1321 took 88.092s, currently going to do 2541
#   training loss: 0.673751, validation loss: 0.415917
#   validation accuracy:		86.39%
#   training accuracy:		88.74%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1322 took 88.032s, currently going to do 2541
#   training loss: 0.662648, validation loss: 0.417167
#   validation accuracy:		86.28%
#   training accuracy:		89.26%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1323 took 88.472s, currently going to do 2541
#   training loss: 0.665522, validation loss: 0.417192
#   validation accuracy:		86.40%
#   training accuracy:		89.13%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1324 took 88.293s, currently going to do 2541
#   training loss: 0.673612, validation loss: 0.416774
#   validation accuracy:		86.36%
#   training accuracy:		89.00%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1325 took 88.263s, currently going to do 2541
#   training loss: 0.668820, validation loss: 0.418728
#   validation accuracy:		86.37%
#   training accuracy:		89.01%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1326 took 88.247s, currently going to do 2541
#   training loss: 0.672527, validation loss: 0.419854
#   validation accuracy:		86.37%
#   training accuracy:		88.86%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1327 took 88.142s, currently going to do 2541
#   training loss: 0.675188, validation loss: 0.420686
#   validation accuracy:		86.31%
#   training accuracy:		88.73%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1328 took 88.670s, currently going to do 2541
#   training loss: 0.680058, validation loss: 0.418098
#   validation accuracy:		86.14%
#   training accuracy:		88.80%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1329 took 63.483s, currently going to do 2541
#   training loss: 0.671702, validation loss: 0.424401
#   validation accuracy:		85.84%
#   training accuracy:		88.93%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1330 took 88.447s, currently going to do 2541
#   training loss: 0.670817, validation loss: 0.421433
#   validation accuracy:		86.16%
#   training accuracy:		89.20%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1331 took 88.687s, currently going to do 2541
#   training loss: 0.665983, validation loss: 0.421212
#   validation accuracy:		86.25%
#   training accuracy:		89.15%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1332 took 88.573s, currently going to do 2541
#   training loss: 0.679394, validation loss: 0.420870
#   validation accuracy:		86.21%
#   training accuracy:		88.67%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1333 took 88.583s, currently going to do 2541
#   training loss: 0.675943, validation loss: 0.422571
#   validation accuracy:		86.12%
#   training accuracy:		88.85%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1334 took 88.599s, currently going to do 2541
#   training loss: 0.669344, validation loss: 0.418931
#   validation accuracy:		86.41%
#   training accuracy:		89.05%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1335 took 89.083s, currently going to do 2541
#   training loss: 0.662397, validation loss: 0.421846
#   validation accuracy:		86.37%
#   training accuracy:		89.33%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1336 took 88.631s, currently going to do 2541
#   training loss: 0.663302, validation loss: 0.421277
#   validation accuracy:		86.29%
#   training accuracy:		89.24%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1337 took 89.690s, currently going to do 2541
#   training loss: 0.671723, validation loss: 0.422289
#   validation accuracy:		86.38%
#   training accuracy:		88.99%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1338 took 89.168s, currently going to do 2541
#   training loss: 0.666037, validation loss: 0.422062
#   validation accuracy:		86.31%
#   training accuracy:		89.17%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1339 took 75.224s, currently going to do 2541
#   training loss: 0.667012, validation loss: 0.421465
#   validation accuracy:		86.11%
#   training accuracy:		89.04%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1340 took 79.620s, currently going to do 2541
#   training loss: 0.664174, validation loss: 0.427201
#   validation accuracy:		86.15%
#   training accuracy:		89.18%
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Epoch 1341 took 89.144s, currently going to do 2541
#   training loss: 0.667261, validation loss: 0.421876
#   validation accuracy:		86.33%
#   training accuracy:		89.14%
# . . . . . . . . . . . . . . . . . . . .
# Keyboard interruption, user stopped learning
# Learning ended at 18:43:11
# Setting network parameters from after epoch 0
# Test error rate: 0.140400%

# %%
t_preds = open('test_predictions', 'w')
i = 0
for X, Y in cifar10_test_stream.get_epoch_iterator():
    preds = net.test_prediction_fn(X)
    for pred, y in zip(preds[0], Y.ravel()):
        t_preds.write(str(np.argmax(pred, axis=0)) + ' ' + str(y) + '\n')
t_preds.close()

# %%
for X_batch, Y_batch in cifar10_train_stream.get_epoch_iterator():
    X = X_batch[:1]
    break

# %%
pylab.rcParams['figure.figsize'] = (15, 12)

conv_and_pool = []
for layer in net.layers:
    if isinstance(layer, LL.Conv2DLayer) or isinstance(layer, LL.MaxPool2DLayer) or isinstance(layer, LL.InputLayer):
        conv_and_pool += [layer]

middle_layers = []
for i in xrange(len(conv_and_pool)):
    middle_layers_computer = theano.function([net.input_var],
                                         [LL.get_output(conv_and_pool[i], inputs=net.input_var, deterministic=True)])
    middle_layers += middle_layers_computer(X)
    

middle_layers[0] = X
for ml, name in zip(middle_layers, ['X', 'C1', 'P1', 'C2', 'P2']):
    plot_mat(ml.transpose(1,0,2,3), cmap='gray')
    title(name)
    show()
# Out:
# 0 (1, 1, 3, 32, 32)
# 1 (1, 1, 50, 28, 28)
# 2 (1, 1, 50, 14, 14)
# 3 (1, 1, 100, 10, 10)
# 4 (1, 1, 100, 5, 5)

# %%
plot_mat(X, cmap='gray')
show()
X_tr = trans[0].transform(X[:])
plot_mat(X_tr, cmap='gray')
show()
X_tr = trans[1].transform(X[:])
plot_mat(X_tr, cmap='gray')
show()
